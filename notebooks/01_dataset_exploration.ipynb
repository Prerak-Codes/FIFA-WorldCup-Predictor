# %%
import pandas as pd

# %%
results = pd.read_csv("../data/raw/international_results/goalscorers.csv")

results.head()
results.info()
results.describe()
results.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47886 entries, 0 to 47885
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       47886 non-null  str
#  1   home_team  47886 non-null  str
#  2   away_team  47886 non-null  str
#  3   team       47886 non-null  str
#  4   scorer     47842 non-null  str
#  5   minute     47632 non-null  float64
#  6   own_goal   47886 non-null  bool
#  7   penalty    47886 non-null  bool
# dtypes: bool(2), float64(1), str(5)
# memory usage: 2.3 MB
# date           0
# home_team      0
# away_team      0
# team           0
# scorer        44
# minute       254
# own_goal       0
# penalty        0
# dtype: int64

# %%
results = pd.read_csv("../data/raw/international_results/former_names.csv")

results.head()
results.info()
results.describe()
results.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   current     36 non-null     str
#  1   former      36 non-null     str
#  2   start_date  36 non-null     str
#  3   end_date    36 non-null     str
# dtypes: str(4)
# memory usage: 1.3 KB
# current       0
# former        0
# start_date    0
# end_date      0
# dtype: int64

# %%
results = pd.read_csv("../data/raw/international_results/results.csv")

results.head()
results.info()
results.describe()
results.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49505 entries, 0 to 49504
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        49505 non-null  str
#  1   home_team   49505 non-null  str
#  2   away_team   49505 non-null  str
#  3   home_score  49501 non-null  float64
#  4   away_score  49501 non-null  float64
#  5   tournament  49505 non-null  str
#  6   city        49505 non-null  str
#  7   country     49505 non-null  str
#  8   neutral     49505 non-null  bool
# dtypes: bool(1), float64(2), str(6)
# memory usage: 3.1 MB
# date          0
# home_team     0
# away_team     0
# home_score    4
# away_score    4
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
results = pd.read_csv("../data/raw/international_results/shootouts.csv")

results.head()
results.info()
results.describe()
results.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           682 non-null    str
#  1   home_team      682 non-null    str
#  2   away_team      682 non-null    str
#  3   winner         682 non-null    str
#  4   first_shooter  260 non-null    str
# dtypes: str(5)
# memory usage: 26.8 KB
# date               0
# home_team          0
# away_team          0
# winner             0
# first_shooter    422
# dtype: int64

# %%
results = pd.read_csv("../data/raw/match_features/player_aggregates.csv")

results.head()
results.info()
results.describe()
results.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              1599 non-null   str
#  1   fifa_version         1599 non-null   int64
#  2   num_players          1599 non-null   int64
#  3   avg_overall          1599 non-null   float64
#  4   max_overall          1599 non-null   int64
#  5   avg_pace             1583 non-null   float64
#  6   avg_shooting         1583 non-null   float64
#  7   avg_passing          1583 non-null   float64
#  8   avg_dribbling        1583 non-null   float64
#  9   avg_defending        1583 non-null   float64
#  10  avg_physic           1583 non-null   float64
#  11  avg_attack_overall   1599 non-null   float64
#  12  avg_defense_overall  1599 non-null   float64
# dtypes: float64(9), int64(3), str(1)
# memory usage: 162.5 KB
# country                 0
# fifa_version            0
# ...

# %%
results = pd.read_csv("../data/raw/match_features/teams_form.csv")

results.head()
results.info()
results.describe()
results.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102094 entries, 0 to 102093
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   team                102094 non-null  str
#  1   match_date          102094 non-null  str
#  2   avg_goals_scored    102094 non-null  float64
#  3   avg_goals_conceded  102094 non-null  float64
#  4   win_rate            102094 non-null  float64
# dtypes: float64(3), str(2)
# memory usage: 3.9 MB
# team                  0
# match_date            0
# avg_goals_scored      0
# avg_goals_conceded    0
# win_rate              0
# dtype: int64

# %%
results = pd.read_csv("../data/raw/match_features/teams_match_features.csv")

results.head()
results.info()
results.describe()
results.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43364 entries, 0 to 43363
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   home_elo            43364 non-null  float64
#  1   away_elo            43364 non-null  float64
#  2   elo_diff            43364 non-null  float64
#  3   home_avg_overall    43364 non-null  float64
#  4   home_max_overall    43364 non-null  int64
#  5   home_avg_attack     43364 non-null  float64
#  6   home_avg_defense    43364 non-null  float64
#  7   home_avg_pace       42667 non-null  float64
#  8   home_avg_shooting   42667 non-null  float64
#  9   home_avg_passing    42667 non-null  float64
#  10  away_avg_overall    43364 non-null  float64
#  11  away_max_overall    43364 non-null  int64
#  12  away_avg_attack     43364 non-null  float64
#  13  away_avg_defense    43364 non-null  float64
#  14  away_avg_pace       42563 non-null  float64
# ...

# %%
results = pd.read_csv("../data/raw/fifa_rankings/fifa_matches.csv")

results.head()
results.info()
results.describe()
results.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25039 entries, 0 to 25038
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   match_id    25039 non-null  int64
#  1   date        25039 non-null  str
#  2   home_team   25039 non-null  str
#  3   away_team   25039 non-null  str
#  4   home_score  25039 non-null  float64
#  5   away_score  25039 non-null  float64
#  6   tournament  25039 non-null  str
#  7   city        25039 non-null  str
#  8   country     25039 non-null  str
#  9   neutral     25039 non-null  bool
# dtypes: bool(1), float64(2), int64(1), str(6)
# memory usage: 1.7 MB
# match_id      0
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
results = pd.read_csv("../data/raw/fifa_rankings/fifa_rankings.csv")

results.head()
results.info()
results.describe()
results.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 63899 entries, 0 to 63898
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rank             63899 non-null  int64
#  1   country_abrv     63899 non-null  str
#  2   total_points     63899 non-null  float64
#  3   previous_points  63899 non-null  float64
#  4   rank_change      63899 non-null  int64
#  5   confederation    63899 non-null  str
#  6   rank_date        63899 non-null  str
#  7   team             63899 non-null  str
# dtypes: float64(2), int64(2), str(4)
# memory usage: 3.9 MB
# rank               0
# country_abrv       0
# total_points       0
# previous_points    0
# rank_change        0
# confederation      0
# rank_date          0
# team               0
# dtype: int64

# %%
results = pd.read_csv("../data/raw/fifa_rankings/fifa_teams.csv")

results.head()
results.info()
results.describe()
results.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   team           211 non-null    str
#  1   code           211 non-null    str
#  2   country        211 non-null    str
#  3   confederation  211 non-null    str
# dtypes: str(4)
# memory usage: 6.7 KB
# team             0
# code             0
# country          0
# confederation    0
# dtype: int64

# %%
results = pd.read_csv("../data/raw/elo_ratings/eloratings.csv")

results.head()
results.info()
results.describe()
results.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6678 entries, 0 to 6677
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6678 non-null   str
#  1   team    6678 non-null   str
#  2   rating  6647 non-null   float64
#  3   change  6678 non-null   int64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 208.8 KB
# date       0
# team       0
# rating    31
# change     0
# dtype: int64
